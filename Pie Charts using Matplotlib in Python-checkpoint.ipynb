# %%
import matplotlib.pyplot as pyplot
# set up the data
labels = ('Cloud Computing','Software Quality','Simulation & Modeling')
sizes = [70, 30, 20] # provides size
# set up the bar data
pyplot.pie(sizes,labels=labels, autopct='%1.f%%', counterclock=False, startangle=105)
# display chart
pyplot.show()
